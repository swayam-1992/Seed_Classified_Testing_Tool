# %%
import os

def get_folder_size_mb(folder_path):
    total_bytes = 0
    for root, _, files in os.walk(folder_path):
        for f in files:
            fp = os.path.join(root, f)
            if os.path.isfile(fp):
                total_bytes += os.path.getsize(fp)
    return total_bytes / (1024 * 1024)


run_dir = "runs/run_20251222_152132"   # <-- change this
size_mb = get_folder_size_mb(run_dir)

print(f"📦 Size of {run_dir}: {size_mb:.2f} MB")
# Out:
# 📦 Size of runs/run_20251222_152132: 5.08 MB
